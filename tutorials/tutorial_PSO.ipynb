# %% [markdown]
# ## PSO optimizer tutorial.
# ### Burgers equation.
# $$\frac{\partial u}{\partial t}+ u\frac{\partial u}{\partial x}=\mu\frac{\partial^2 u}{\partial x^2} $$
# $$\mu=0.02/\pi$$
# $$x\in[-1,1]$$
# $$t\in[0,1]$$
#
# *Initial and boundary conditions*
# $$u(x, t=0)=-sin(\pi*x)$$
# $$u(x=-1, t)=0$$
# $$u(x=1, t)=0$$
#
# import libraries and Solver modules.

# %%
import torch
import numpy as np
from scipy.integrate import quad
import sys
import os

os.environ['KMP_DUPLICATE_LIB_OK'] = 'TRUE'
sys.path.append(os.path.abspath(os.path.join(os.path.dirname('tutorials'), '..')))

from tedeous.data import Domain, Conditions, Equation
from tedeous.model import Model
from tedeous.callbacks import early_stopping, plot
from tedeous.optimizers.optimizer import Optimizer
from tedeous.device import solver_device, check_device
from tedeous.models import mat_model

# %% [markdown]
# Building grid, boundary conditions, equation.

# %%
solver_device('cuda')

mode = 'autograd'

mu = 0.02 / np.pi

##Domain class for doamin initialization
domain = Domain()
domain.variable('x', [-1, 1], 20)
domain.variable('t', [0, 1], 20)

boundaries = Conditions()

##initial cond
x = domain.variable_dict['x']
boundaries.dirichlet({'x': [-1, 1], 't': 0}, value=-torch.sin(np.pi*x))

##boundary cond
boundaries.dirichlet({'x': -1, 't': [0, 1]}, value=0)

##boundary cond
boundaries.dirichlet({'x': 1, 't': [0, 1]}, value=0)

equation = Equation()

## equation part
burgers_eq = {
    'du/dt**1':
        {
            'coeff': 1.,
            'du/dt': [1],
            'pow': 1,
            'var': 0
        },
    '+u*du/dx':
        {
            'coeff': 1,
            'u*du/dx': [[None], [0]],
            'pow': [1, 1],
            'var': [0, 0]
        },
    '-mu*d2u/dx2':
        {
            'coeff': -mu,
            'd2u/dx2': [0, 0],
            'pow': 1,
            'var': 0
        }
}

equation.add(burgers_eq)
# Out:
# CUDA is available and used.

# %% [markdown]
# exact solution

# %%
def exact(grid):
    mu = 0.02 / np.pi

    def f(y):
        return np.exp(-np.cos(np.pi * y) / (2 * np.pi * mu))

    def integrand1(m, x, t):
        return np.sin(np.pi * (x - m)) * f(x - m) * np.exp(-m ** 2 / (4 * mu * t))

    def integrand2(m, x, t):
        return f(x - m) * np.exp(-m ** 2 / (4 * mu * t))

    def u(x, t):
        if t == 0:
            return -np.sin(np.pi * x)
        else:
            return -quad(integrand1, -np.inf, np.inf, args=(x, t))[0] / quad(integrand2, -np.inf, np.inf, args=(x, t))[
                0]

    solution = []
    for point in grid:
        solution.append(u(point[0].item(), point[1].item()))

    return torch.tensor(solution)

# %% [markdown]
# When grid, equation, boundary conditions  exist, we should call preprocessing class Equation with method set_strategy and initialize model.

# %%
## model part
if mode in ('NN', 'autograd'):
    net = torch.nn.Sequential(
        torch.nn.Linear(2, 10),
        torch.nn.Tanh(),
        torch.nn.Linear(10, 10),
        torch.nn.Tanh(),
        torch.nn.Linear(10, 10),
        torch.nn.Tanh(),
        torch.nn.Linear(10, 1)
    )
else:
    net = mat_model(domain, equation)

# %% [markdown]
# After that, we can initialize optimizer, it may be one of torch optimizers or custom form *tedeous.optimizers* module.
# If you want to run optimizatoin process with default settings,
# you will be able to set it as string ("Adam", "SGD", "LBFGS", "PSO")
#
# *Here is main aspects of particle swarm optimizer realization*
# 1. For optimization, the swarm *pop_size* is built based on initial model weights with adding some *variance* (influence on search space)
# 2. Each individual in this swarm represents a candidate solution. At each iteration, the particles in the swarm exchange
# information and use it to update their positions.
# 3.  Particle $\theta^t$ at iteration $t$ is changed by three factors: its own velocity inertia $\beta \upsilon^t$
# , its best-known position $p_{best}$ in the search-space, as well as the
# entire swarm’s best-known position $g_{best}$:
# $$\upsilon^{t+1} = \beta*\upsilon^{t} + (1-\beta)*(c1*r1(p_{best} − \theta^t) + c2*r2(g_{best} − \theta^t))$$
# where *c1* and *c2* are the cognitive and social coefficients, respectively, referred to jointly as the behavioral
# coefficients, and *r1* and *r2* are uniformly distributed random numbers in range (-*variance*, *variance*). Then the particle position is updated as:
# $$\theta^{t+1} = \theta^t + \upsilon^{t+1}$$
# 4. PSO can be combined with gradient descent to train neural networks:
# $$v^{t+1} = \beta*\upsilon^{t} + (1-\beta)*(c1*r1(p_{best} − \theta^t) + c2*r2(g_{best} − \theta^t)) − \alpha*\nabla Loss(\theta^t)$$
# where $\alpha$ is *lr*.
#
# Based on formulaes above, here is matching formulaes coef-nts with *PSO* algorithm parameters:
# 1. pop_size (int, optional): The swarm. Defaults to 30.
# 2. b (float, optional): Inertia of the particles. Defaults to 0.9.
# 3. c1 (float, optional): The *p-best* coeficient. Defaults to 0.08.
# 4. c2 (float, optional): The *g-best* coeficient. Defaults to 0.5.
# 5. c_decrease (bool, optional): Flag for update_pso_params method. Defautls to False.
# 6. variance (float, optional): Variance parameter for swarm creation
# based on init model, ifluence on r1 and r2 coeff-nts. Defaults to 1.
# 7. lr (float, optional): Learning rate for gradient descent. Defaults to 1e-3.
#     If 0, there will be only PSO optimization without gradients.
# 8. epsilon (float, optional): some add to gradient descent like in Adam optimizer. Defaults to 1e-8.
#
# After preliminaries, to sart solving the equation, we should call Solver class with method solve:

# %%
img_dir=os.path.join(os.path.dirname('tutorials'), 'Burg_eq_img')

model = Model(net, domain, equation, boundaries)

model.compile(mode, lambda_operator=1, lambda_bound=10)

cb_es = early_stopping.EarlyStopping(eps=1e-7,
                                     loss_window=100,
                                     no_improvement_patience=1000,
                                     patience=3,
                                     randomize_parameter=1e-5,
                                     info_string_every=1000)

cb_plots = plot.Plots(save_every=1000, print_every=None, img_dir=img_dir)

# %%
optimizer = Optimizer('Adam', {'lr': 1e-3})

model.train(optimizer, 10000, save_model=False, callbacks=[cb_es, cb_plots])

grid = domain.build(mode)

u_exact = exact(grid).to('cuda')

u_exact = check_device(u_exact).reshape(-1)

u_pred = check_device(net(grid)).reshape(-1)

error_rmse = torch.sqrt(torch.sum((u_exact - u_pred)**2)) / torch.sqrt(torch.sum(u_exact**2))

print('RMSE_grad= ', error_rmse.item())
# Out:
# [2024-05-11 00:09:18.373698] initial (min) loss is 4.058678150177002
# [2024-05-11 00:09:37.501029] Step = 1000 loss = 0.265380 normalized loss line= -0.000479x+1.050024. There was 0 stop dings already.
# [2024-05-11 00:09:56.623818] Step = 2000 loss = 0.183178 normalized loss line= -0.000267x+1.028287. There was 0 stop dings already.
# [2024-05-11 00:10:13.856850] Step = 3000 loss = 0.137374 normalized loss line= -0.000589x+1.064996. There was 0 stop dings already.
# [2024-05-11 00:10:31.337792] Step = 4000 loss = 0.029479 normalized loss line= -0.001481x+1.153410. There was 0 stop dings already.
# [2024-05-11 00:10:48.801780] Step = 5000 loss = 0.009205 normalized loss line= 0.000204x+1.063518. There was 0 stop dings already.
# [2024-05-11 00:11:06.691818] Step = 6000 loss = 0.005344 normalized loss line= -0.000862x+1.123907. There was 0 stop dings already.
# [2024-05-11 00:11:24.454755] Step = 7000 loss = 0.004046 normalized loss line= -0.000225x+1.023839. There was 0 stop dings already.
# [2024-05-11 00:11:42.128651] Step = 8000 loss = 0.003250 normalized loss line= 0.001009x+1.043274. There was 0 stop dings already.
# [2024-05-11 00:12:01.867641] Step = 9000 loss = 0.002702 normalized loss line= -0.000643x+1.088017. There was 0 stop dings already.
# C:\Users\Рустам\AppData\Local\Temp\ipykernel_28972\2125334694.py:17: IntegrationWarning: The maximum number of subdivisions (50) has been achieved.
#   If increasing the limit yields no improvement it is advised to analyze
#   the integrand in order to determine the difficulties.  If the position of a
#   local difficulty can be determined (singularity, discontinuity) one will
#   probably gain from splitting up the interval and calling the integrator
#   on the subranges.  Perhaps a special-purpose integrator should be used.
#   return -quad(integrand1, -np.inf, np.inf, args=(x, t))[0] / quad(integrand2, -np.inf, np.inf, args=(x, t))[
# C:\Users\Рустам\AppData\Local\Temp\ipykernel_28972\2125334694.py:17: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   return -quad(integrand1, -np.inf, np.inf, args=(x, t))[0] / quad(integrand2, -np.inf, np.inf, args=(x, t))[
# RMSE_grad=  0.0375038145958498

# %% [markdown]
# for trained model we want to start PSO.

# %%
optimizer = Optimizer('PSO', {'pop_size': 10,
                              'b': 0.5,
                              'c2': 0.05,
                              'variance': 5e-3,
                              'c_decrease': True,
                              'lr': 5e-3})

model.train(optimizer, 3000, info_string_every=100, save_model=False, callbacks=[cb_es, cb_plots])

u_pred = check_device(net(grid)).reshape(-1)

error_rmse = torch.sqrt(torch.sum((u_exact - u_pred)**2)) / torch.sqrt(torch.sum(u_exact**2))

print('RMSE_pso= ', error_rmse.item())
# Out:
# [2024-05-11 00:12:26.328809] initial (min) loss is 0.007288636174052954
# ---------------------------------------------------
# tensor([0.0096, 0.0078, 0.0167, 0.0176, 0.0119, 0.0064, 0.0077, 0.0339, 0.0096,
#         0.0157], device='cuda:0')
# tensor([3.8948, 3.0308, 3.5419, 0.5601, 3.0309, 1.3399, 2.8512, 2.5814, 2.9880,
#         2.9912], device='cuda:0')
# tensor(0.0064, device='cuda:0')
# tensor([0.0008], device='cuda:0')
# ---------------------------------------------------
# tensor([0.0096, 0.0078, 0.0167, 0.0176, 0.0119, 0.0064, 0.0077, 0.0339, 0.0096,
#         0.0157], device='cuda:0')
# tensor([0.6091, 0.1961, 0.9056, 2.3373, 0.1865, 2.4077, 0.1736, 0.0821, 0.2306,
#         0.1504], device='cuda:0')
# tensor(0.0064, device='cuda:0')
# tensor([0.0053], device='cuda:0')
# ---------------------------------------------------
# tensor([0.0096, 0.0078, 0.0167, 0.0176, 0.0119, 0.0064, 0.0077, 0.0339, 0.0096,
#         0.0157], device='cuda:0')
# tensor([1.5609, 0.5878, 1.2190, 0.7047, 0.5723, 0.0776, 0.6422, 1.0036, 0.5005,
#         0.6993], device='cuda:0')
# tensor(0.0064, device='cuda:0')
# tensor([0.0021], device='cuda:0')
# ---------------------------------------------------
# tensor([0.0096, 0.0078, 0.0167, 0.0176, 0.0119, 0.0064, 0.0077, 0.0339, 0.0096,
#         0.0157], device='cuda:0')
# tensor([0.1255, 0.1775, 0.0753, 0.9965, 0.1725, 0.5029, 0.2116, 0.1708, 0.1587,
#         0.1762], device='cuda:0')
# tensor(0.0064, device='cuda:0')
# tensor([0.0259], device='cuda:0')
# ---------------------------------------------------
# tensor([0.0096, 0.0078, 0.0167, 0.0176, 0.0119, 0.0064, 0.0077, 0.0339, 0.0096,
#         0.0157], device='cuda:0')
# tensor([0.1804, 0.1348, 0.2973, 0.0639, 0.1315, 0.2993, 0.1256, 0.1443, 0.1222,
#         0.1285], device='cuda:0')
# tensor(0.0064, device='cuda:0')
# tensor([0.0180], device='cuda:0')
# ---------------------------------------------------
# tensor([0.0096, 0.0078, 0.0167, 0.0176, 0.0119, 0.0064, 0.0077, 0.0339, 0.0096,
#         0.0157], device='cuda:0')
# tensor([0.2058, 0.1441, 0.1806, 0.3579, 0.1269, 0.0864, 0.1213, 0.1562, 0.1282,
#         0.1377], device='cuda:0')
# tensor(0.0064, device='cuda:0')
# tensor([0.0158], device='cuda:0')
# ---------------------------------------------------
# tensor([0.0096, 0.0078, 0.0167, 0.0176, 0.0119, 0.0064, 0.0077, 0.0339, 0.0096,
#         0.0157], device='cuda:0')
# tensor([0.0611, 0.1280, 0.0562, 0.0779, 0.1249, 0.0679, 0.1182, 0.1376, 0.1274,
#         0.1276], device='cuda:0')
# tensor(0.0064, device='cuda:0')
# tensor([0.0531], device='cuda:0')
# ---------------------------------------------------
# tensor([0.0096, 0.0078, 0.0167, 0.0176, 0.0119, 0.0064, 0.0077, 0.0339, 0.0096,
#         0.0157], device='cuda:0')
# tensor([0.0431, 0.1245, 0.0501, 0.0689, 0.1275, 0.0482, 0.1226, 0.1304, 0.1251,
#         0.1178], device='cuda:0')
# tensor(0.0064, device='cuda:0')
# tensor([0.0753], device='cuda:0')
# ---------------------------------------------------
# tensor([0.0096, 0.0078, 0.0167, 0.0176, 0.0119, 0.0064, 0.0077, 0.0339, 0.0096,
#         0.0157], device='cuda:0')
# tensor([0.0447, 0.1296, 0.0626, 0.0476, 0.1209, 0.0265, 0.1252, 0.1302, 0.1244,
#         0.1208], device='cuda:0')
# tensor(0.0064, device='cuda:0')
# tensor([0.0727], device='cuda:0')
# ---------------------------------------------------
# tensor([0.0096, 0.0078, 0.0167, 0.0134, 0.0119, 0.0064, 0.0077, 0.0339, 0.0096,
#         0.0157], device='cuda:0')
# tensor([0.0333, 0.1320, 0.0390, 0.0134, 0.1426, 0.0320, 0.1545, 0.1225, 0.1302,
#         0.1214], device='cuda:0')
# tensor(0.0064, device='cuda:0')
# tensor([0.0975], device='cuda:0')
# ---------------------------------------------------
# tensor([0.0096, 0.0078, 0.0167, 0.0134, 0.0119, 0.0064, 0.0077, 0.0339, 0.0096,
#         0.0157], device='cuda:0')
# tensor([0.0286, 0.1573, 0.0390, 0.0714, 0.1632, 0.0255, 0.1456, 0.1386, 0.1526,
#         0.1320], device='cuda:0')
# tensor(0.0064, device='cuda:0')
# tensor([0.1133], device='cuda:0')
# ---------------------------------------------------
# tensor([0.0096, 0.0078, 0.0167, 0.0134, 0.0119, 0.0064, 0.0077, 0.0339, 0.0096,
#         0.0157], device='cuda:0')
# tensor([0.0358, 0.1541, 0.0438, 0.0225, 0.1858, 0.0292, 0.1881, 0.1634, 0.2082,
#         0.1553], device='cuda:0')
# tensor(0.0064, device='cuda:0')
# tensor([0.0906], device='cuda:0')
# ---------------------------------------------------
# tensor([0.0096, 0.0078, 0.0167, 0.0134, 0.0119, 0.0064, 0.0077, 0.0339, 0.0096,
#         0.0157], device='cuda:0')
# tensor([0.0308, 0.1617, 0.0335, 0.0669, 0.1626, 0.0254, 0.1957, 0.1793, 0.1782,
#         0.1871], device='cuda:0')
# tensor(0.0064, device='cuda:0')
# tensor([0.1052], device='cuda:0')
# ---------------------------------------------------
# tensor([0.0096, 0.0078, 0.0167, 0.0134, 0.0119, 0.0064, 0.0077, 0.0339, 0.0096,
#         0.0157], device='cuda:0')
# tensor([0.0292, 0.1716, 0.0319, 0.0304, 0.1615, 0.0279, 0.1525, 0.2040, 0.1682,
#         0.1874], device='cuda:0')
# tensor(0.0064, device='cuda:0')
# tensor([0.1113], device='cuda:0')
# ---------------------------------------------------
# tensor([0.0096, 0.0078, 0.0167, 0.0134, 0.0119, 0.0064, 0.0077, 0.0339, 0.0096,
#         0.0157], device='cuda:0')
# tensor([0.0300, 0.1805, 0.0311, 0.0229, 0.1480, 0.0312, 0.1414, 0.2006, 0.1373,
#         0.1796], device='cuda:0')
# tensor(0.0064, device='cuda:0')
# tensor([0.1083], device='cuda:0')
# ---------------------------------------------------
# tensor([0.0096, 0.0078, 0.0167, 0.0134, 0.0119, 0.0064, 0.0077, 0.0339, 0.0096,
#         0.0157], device='cuda:0')
# tensor([0.0277, 0.1447, 0.0311, 0.0300, 0.1370, 0.0329, 0.1195, 0.1484, 0.1249,
#         0.1704], device='cuda:0')
# tensor(0.0064, device='cuda:0')
# tensor([0.1174], device='cuda:0')
# ---------------------------------------------------
# tensor([0.0096, 0.0078, 0.0167, 0.0134, 0.0119, 0.0064, 0.0077, 0.0339, 0.0096,
#         0.0157], device='cuda:0')
# tensor([0.0278, 0.1292, 0.0272, 0.0172, 0.1240, 0.0374, 0.1046, 0.1264, 0.1113,
#         0.1415], device='cuda:0')
# tensor(0.0064, device='cuda:0')
# tensor([0.1167], device='cuda:0')
# ---------------------------------------------------
# tensor([0.0096, 0.0078, 0.0167, 0.0134, 0.0119, 0.0064, 0.0077, 0.0339, 0.0096,
#         0.0157], device='cuda:0')
# tensor([0.0270, 0.1192, 0.0289, 0.0193, 0.1042, 0.0298, 0.1013, 0.1093, 0.1054,
#         0.1205], device='cuda:0')
# tensor(0.0064, device='cuda:0')
# tensor([0.1202], device='cuda:0')
# ---------------------------------------------------
# tensor([0.0096, 0.0078, 0.0167, 0.0134, 0.0119, 0.0064, 0.0077, 0.0339, 0.0096,
#         0.0157], device='cuda:0')
# tensor([0.0269, 0.1039, 0.0270, 0.0178, 0.0933, 0.0308, 0.0933, 0.1033, 0.0964,
#         0.1037], device='cuda:0')
# tensor(0.0064, device='cuda:0')
# tensor([0.1208], device='cuda:0')
# ---------------------------------------------------
# tensor([0.0096, 0.0078, 0.0167, 0.0134, 0.0119, 0.0064, 0.0077, 0.0339, 0.0096,
#         0.0157], device='cuda:0')
# tensor([0.0265, 0.0993, 0.0263, 0.0189, 0.0868, 0.0314, 0.0881, 0.0989, 0.0940,
#         0.0936], device='cuda:0')
# tensor(0.0064, device='cuda:0')
# tensor([0.1225], device='cuda:0')
# ---------------------------------------------------
# tensor([0.0096, 0.0078, 0.0167, 0.0134, 0.0119, 0.0064, 0.0077, 0.0339, 0.0096,
#         0.0157], device='cuda:0')
# tensor([0.0288, 0.0889, 0.0266, 0.0188, 0.0964, 0.0315, 0.0825, 0.0989, 0.0950,
#         0.0988], device='cuda:0')
# tensor(0.0064, device='cuda:0')
# tensor([0.1128], device='cuda:0')
# ---------------------------------------------------
# tensor([0.0096, 0.0078, 0.0167, 0.0134, 0.0119, 0.0064, 0.0077, 0.0339, 0.0096,
#         0.0157], device='cuda:0')
# tensor([0.0279, 0.0819, 0.0278, 0.0178, 0.0810, 0.0317, 0.0851, 0.0887, 0.0901,
#         0.0878], device='cuda:0')
# tensor(0.0064, device='cuda:0')
# tensor([0.1162], device='cuda:0')
# ---------------------------------------------------
# tensor([0.0096, 0.0078, 0.0167, 0.0134, 0.0119, 0.0064, 0.0077, 0.0339, 0.0096,
#         0.0157], device='cuda:0')
# tensor([0.0277, 0.0796, 0.0262, 0.0179, 0.0782, 0.0312, 0.0752, 0.0796, 0.0872,
#         0.0837], device='cuda:0')
# tensor(0.0064, device='cuda:0')
# tensor([0.1173], device='cuda:0')
# ---------------------------------------------------
# tensor([0.0096, 0.0078, 0.0167, 0.0134, 0.0119, 0.0064, 0.0077, 0.0339, 0.0096,
#         0.0157], device='cuda:0')
# tensor([0.0260, 0.0772, 0.0257, 0.0182, 0.0745, 0.0295, 0.0743, 0.0802, 0.0814,
#         0.0790], device='cuda:0')
# tensor(0.0064, device='cuda:0')
# tensor([0.1247], device='cuda:0')
# ---------------------------------------------------
# tensor([0.0096, 0.0078, 0.0167, 0.0134, 0.0119, 0.0064, 0.0077, 0.0339, 0.0096,
#         0.0157], device='cuda:0')
# tensor([0.0253, 0.0768, 0.0262, 0.0182, 0.0731, 0.0283, 0.0691, 0.0767, 0.0783,
#         0.0757], device='cuda:0')
# tensor(0.0064, device='cuda:0')
# tensor([0.1283], device='cuda:0')
# ---------------------------------------------------
# tensor([0.0096, 0.0078, 0.0167, 0.0134, 0.0119, 0.0064, 0.0077, 0.0339, 0.0096,
#         0.0157], device='cuda:0')
# tensor([0.0248, 0.0729, 0.0254, 0.0185, 0.0717, 0.0292, 0.0683, 0.0787, 0.0763,
#         0.0732], device='cuda:0')
# tensor(0.0064, device='cuda:0')
# tensor([0.1310], device='cuda:0')
# ---------------------------------------------------
# tensor([0.0096, 0.0078, 0.0167, 0.0134, 0.0119, 0.0064, 0.0077, 0.0339, 0.0096,
#         0.0157], device='cuda:0')
# tensor([0.0252, 0.0776, 0.0255, 0.0192, 0.0707, 0.0320, 0.0666, 0.0797, 0.0794,
#         0.0744], device='cuda:0')
# tensor(0.0064, device='cuda:0')
# tensor([0.1289], device='cuda:0')
# ---------------------------------------------------
# tensor([0.0096, 0.0078, 0.0167, 0.0134, 0.0119, 0.0064, 0.0077, 0.0339, 0.0096,
#         0.0157], device='cuda:0')
# tensor([0.0234, 0.0750, 0.0251, 0.0190, 0.0690, 0.0280, 0.0671, 0.0810, 0.0733,
#         0.0751], device='cuda:0')
# tensor(0.0064, device='cuda:0')
# tensor([0.1388], device='cuda:0')
# ---------------------------------------------------
# tensor([0.0096, 0.0078, 0.0167, 0.0134, 0.0119, 0.0064, 0.0077, 0.0339, 0.0096,
#         0.0157], device='cuda:0')
# tensor([0.0236, 0.0767, 0.0240, 0.0189, 0.0673, 0.0292, 0.0666, 0.0726, 0.0716,
#         0.0731], device='cuda:0')
# tensor(0.0064, device='cuda:0')
# tensor([0.1373], device='cuda:0')
# ---------------------------------------------------
# tensor([0.0096, 0.0078, 0.0167, 0.0134, 0.0119, 0.0064, 0.0077, 0.0339, 0.0096,
#         0.0157], device='cuda:0')
# tensor([0.0248, 0.0716, 0.0251, 0.0191, 0.0696, 0.0299, 0.0646, 0.0711, 0.0694,
#         0.0718], device='cuda:0')
# tensor(0.0064, device='cuda:0')
# tensor([0.1311], device='cuda:0')
# ---------------------------------------------------
# tensor([0.0096, 0.0078, 0.0167, 0.0134, 0.0119, 0.0064, 0.0077, 0.0339, 0.0096,
#         0.0157], device='cuda:0')
# tensor([0.0234, 0.0694, 0.0245, 0.0187, 0.0685, 0.0294, 0.0675, 0.0727, 0.0671,
#         0.0691], device='cuda:0')
# tensor(0.0064, device='cuda:0')
# tensor([0.1389], device='cuda:0')
# ---------------------------------------------------
# tensor([0.0096, 0.0078, 0.0167, 0.0134, 0.0119, 0.0064, 0.0077, 0.0339, 0.0096,
#         0.0157], device='cuda:0')
# tensor([0.0252, 0.0718, 0.0243, 0.0190, 0.0669, 0.0281, 0.0657, 0.0704, 0.0664,
#         0.0818], device='cuda:0')
# tensor(0.0064, device='cuda:0')
# tensor([0.1286], device='cuda:0')
# ---------------------------------------------------
# tensor([0.0096, 0.0078, 0.0167, 0.0134, 0.0119, 0.0064, 0.0077, 0.0339, 0.0096,
#         0.0157], device='cuda:0')
# tensor([0.0239, 0.0680, 0.0238, 0.0193, 0.0685, 0.0285, 0.0615, 0.0737, 0.0662,
#         0.0693], device='cuda:0')
# tensor(0.0064, device='cuda:0')
# tensor([0.1359], device='cuda:0')
# ---------------------------------------------------
# tensor([0.0096, 0.0078, 0.0167, 0.0134, 0.0119, 0.0064, 0.0077, 0.0339, 0.0096,
#         0.0157], device='cuda:0')
# tensor([0.0236, 0.0676, 0.0232, 0.0198, 0.0672, 0.0280, 0.0644, 0.0778, 0.0666,
#         0.0690], device='cuda:0')
# tensor(0.0064, device='cuda:0')
# tensor([0.1378], device='cuda:0')
# ---------------------------------------------------
# tensor([0.0096, 0.0078, 0.0167, 0.0134, 0.0119, 0.0064, 0.0077, 0.0339, 0.0096,
#         0.0157], device='cuda:0')
# tensor([0.0231, 0.0644, 0.0262, 0.0196, 0.0668, 0.0285, 0.0633, 0.0733, 0.0654,
#         0.0712], device='cuda:0')
# tensor(0.0064, device='cuda:0')
# tensor([0.1403], device='cuda:0')
# ---------------------------------------------------
# tensor([0.0096, 0.0078, 0.0167, 0.0134, 0.0119, 0.0064, 0.0077, 0.0339, 0.0096,
#         0.0157], device='cuda:0')
# tensor([0.0241, 0.0636, 0.0234, 0.0200, 0.0656, 0.0276, 0.0614, 0.0694, 0.0707,
#         0.0695], device='cuda:0')
# tensor(0.0064, device='cuda:0')
# tensor([0.1346], device='cuda:0')
# ---------------------------------------------------
# tensor([0.0096, 0.0078, 0.0167, 0.0134, 0.0119, 0.0064, 0.0077, 0.0339, 0.0096,
#         0.0157], device='cuda:0')
# tensor([0.0240, 0.0631, 0.0268, 0.0198, 0.0641, 0.0278, 0.0625, 0.0682, 0.0669,
#         0.0685], device='cuda:0')
# tensor(0.0064, device='cuda:0')
# tensor([0.1352], device='cuda:0')
# ---------------------------------------------------
# tensor([0.0096, 0.0078, 0.0167, 0.0134, 0.0119, 0.0064, 0.0077, 0.0339, 0.0096,
#         0.0157], device='cuda:0')
# tensor([0.0256, 0.0667, 0.0245, 0.0206, 0.0647, 0.0292, 0.0621, 0.0699, 0.0641,
#         0.0738], device='cuda:0')
# tensor(0.0064, device='cuda:0')
# tensor([0.1270], device='cuda:0')
# ---------------------------------------------------
# tensor([0.0096, 0.0078, 0.0167, 0.0134, 0.0119, 0.0064, 0.0077, 0.0339, 0.0096,
#         0.0157], device='cuda:0')
# tensor([0.0259, 0.0701, 0.0271, 0.0208, 0.0607, 0.0266, 0.0614, 0.0715, 0.0658,
#         0.0662], device='cuda:0')
# tensor(0.0064, device='cuda:0')
# tensor([0.1251], device='cuda:0')
# ---------------------------------------------------
# tensor([0.0096, 0.0078, 0.0167, 0.0134, 0.0119, 0.0064, 0.0077, 0.0339, 0.0096,
#         0.0157], device='cuda:0')
# tensor([0.0251, 0.0641, 0.0264, 0.0198, 0.0615, 0.0259, 0.0628, 0.0729, 0.0630,
#         0.0678], device='cuda:0')
# tensor(0.0064, device='cuda:0')
# tensor([0.1292], device='cuda:0')
# ---------------------------------------------------
# tensor([0.0096, 0.0078, 0.0167, 0.0134, 0.0119, 0.0064, 0.0077, 0.0339, 0.0096,
#         0.0157], device='cuda:0')
# tensor([0.0254, 0.0589, 0.0248, 0.0205, 0.0639, 0.0274, 0.0596, 0.0707, 0.0599,
#         0.0658], device='cuda:0')
# tensor(0.0064, device='cuda:0')
# tensor([0.1276], device='cuda:0')
# ---------------------------------------------------
# tensor([0.0096, 0.0078, 0.0167, 0.0134, 0.0119, 0.0064, 0.0077, 0.0339, 0.0096,
#         0.0157], device='cuda:0')
# tensor([0.0265, 0.0699, 0.0270, 0.0210, 0.0626, 0.0269, 0.0608, 0.0743, 0.0597,
#         0.0624], device='cuda:0')
# tensor(0.0064, device='cuda:0')
# tensor([0.1223], device='cuda:0')
# ---------------------------------------------------
# tensor([0.0096, 0.0078, 0.0167, 0.0134, 0.0119, 0.0064, 0.0077, 0.0339, 0.0096,
#         0.0157], device='cuda:0')
# tensor([0.0270, 0.0596, 0.0255, 0.0196, 0.0627, 0.0250, 0.0650, 0.0664, 0.0573,
#         0.0624], device='cuda:0')
# tensor(0.0064, device='cuda:0')
# tensor([0.1202], device='cuda:0')
# ---------------------------------------------------
# tensor([0.0096, 0.0078, 0.0167, 0.0134, 0.0119, 0.0064, 0.0077, 0.0339, 0.0096,
#         0.0157], device='cuda:0')
# tensor([0.0236, 0.0587, 0.0277, 0.0199, 0.0610, 0.0258, 0.0579, 0.0770, 0.0568,
#         0.0630], device='cuda:0')
# tensor(0.0064, device='cuda:0')
# tensor([0.1375], device='cuda:0')
# ---------------------------------------------------
# tensor([0.0096, 0.0078, 0.0167, 0.0134, 0.0119, 0.0064, 0.0077, 0.0339, 0.0096,
#         0.0157], device='cuda:0')
# tensor([0.0237, 0.0571, 0.0270, 0.0197, 0.0589, 0.0234, 0.0559, 0.0717, 0.0558,
#         0.0635], device='cuda:0')
# tensor(0.0064, device='cuda:0')
# tensor([0.1371], device='cuda:0')
# ---------------------------------------------------
# tensor([0.0096, 0.0078, 0.0167, 0.0134, 0.0119, 0.0064, 0.0077, 0.0339, 0.0096,
#         0.0157], device='cuda:0')
# tensor([0.0259, 0.0587, 0.0255, 0.0200, 0.0580, 0.0232, 0.0572, 0.0670, 0.0546,
#         0.0608], device='cuda:0')
# tensor(0.0064, device='cuda:0')
# tensor([0.1253], device='cuda:0')
# ---------------------------------------------------
# tensor([0.0096, 0.0078, 0.0167, 0.0134, 0.0119, 0.0064, 0.0077, 0.0339, 0.0096,
#         0.0157], device='cuda:0')
# tensor([0.0235, 0.0568, 0.0251, 0.0197, 0.0604, 0.0228, 0.0576, 0.0645, 0.0554,
#         0.0579], device='cuda:0')
# tensor(0.0064, device='cuda:0')
# tensor([0.1383], device='cuda:0')
# ---------------------------------------------------
# tensor([0.0096, 0.0078, 0.0167, 0.0134, 0.0119, 0.0064, 0.0077, 0.0339, 0.0096,
#         0.0157], device='cuda:0')
# tensor([0.0249, 0.0550, 0.0256, 0.0193, 0.0563, 0.0227, 0.0531, 0.0638, 0.0536,
#         0.0608], device='cuda:0')
# tensor(0.0064, device='cuda:0')
# tensor([0.1304], device='cuda:0')
# ---------------------------------------------------
# tensor([0.0096, 0.0078, 0.0167, 0.0134, 0.0119, 0.0064, 0.0077, 0.0339, 0.0096,
#         0.0157], device='cuda:0')
# tensor([0.0244, 0.0544, 0.0256, 0.0194, 0.0544, 0.0240, 0.0540, 0.0647, 0.0507,
#         0.0562], device='cuda:0')
# tensor(0.0064, device='cuda:0')
# tensor([0.1333], device='cuda:0')
# ---------------------------------------------------
# tensor([0.0096, 0.0078, 0.0167, 0.0134, 0.0119, 0.0064, 0.0077, 0.0339, 0.0096,
#         0.0157], device='cuda:0')
# tensor([0.0242, 0.0545, 0.0261, 0.0187, 0.0571, 0.0222, 0.0525, 0.0618, 0.0512,
#         0.0565], device='cuda:0')
# tensor(0.0064, device='cuda:0')
# tensor([0.1339], device='cuda:0')
# ---------------------------------------------------
# tensor([0.0096, 0.0078, 0.0167, 0.0134, 0.0119, 0.0064, 0.0077, 0.0339, 0.0096,
#         0.0157], device='cuda:0')
# tensor([0.0225, 0.0524, 0.0263, 0.0185, 0.0554, 0.0214, 0.0526, 0.0600, 0.0495,
#         0.0547], device='cuda:0')
# tensor(0.0064, device='cuda:0')
# tensor([0.1440], device='cuda:0')
# ---------------------------------------------------
# tensor([0.0096, 0.0078, 0.0167, 0.0134, 0.0119, 0.0064, 0.0077, 0.0339, 0.0096,
#         0.0157], device='cuda:0')
# tensor([0.0225, 0.0510, 0.0256, 0.0186, 0.0526, 0.0212, 0.0498, 0.0598, 0.0483,
#         0.0533], device='cuda:0')
# tensor(0.0064, device='cuda:0')
# tensor([0.1445], device='cuda:0')
# ---------------------------------------------------
# tensor([0.0096, 0.0078, 0.0167, 0.0134, 0.0119, 0.0064, 0.0077, 0.0339, 0.0096,
#         0.0157], device='cuda:0')
# tensor([0.0220, 0.0533, 0.0259, 0.0182, 0.0558, 0.0205, 0.0480, 0.0583, 0.0470,
#         0.0533], device='cuda:0')
# tensor(0.0064, device='cuda:0')
# tensor([0.1479], device='cuda:0')
# ---------------------------------------------------
# tensor([0.0096, 0.0078, 0.0167, 0.0134, 0.0119, 0.0064, 0.0077, 0.0339, 0.0096,
#         0.0157], device='cuda:0')
# tensor([0.0222, 0.0542, 0.0258, 0.0192, 0.0507, 0.0205, 0.0481, 0.0614, 0.0461,
#         0.0509], device='cuda:0')
# tensor(0.0064, device='cuda:0')
# tensor([0.1463], device='cuda:0')
# ---------------------------------------------------
# tensor([0.0096, 0.0078, 0.0167, 0.0134, 0.0119, 0.0064, 0.0077, 0.0339, 0.0096,
#         0.0157], device='cuda:0')
# tensor([0.0227, 0.0482, 0.0252, 0.0185, 0.0506, 0.0198, 0.0477, 0.0567, 0.0461,
#         0.0504], device='cuda:0')
# tensor(0.0064, device='cuda:0')
# tensor([0.1430], device='cuda:0')
# ---------------------------------------------------
# tensor([0.0096, 0.0078, 0.0167, 0.0134, 0.0119, 0.0064, 0.0077, 0.0339, 0.0096,
#         0.0157], device='cuda:0')
# tensor([0.0226, 0.0490, 0.0242, 0.0177, 0.0507, 0.0190, 0.0462, 0.0575, 0.0468,
#         0.0483], device='cuda:0')
# tensor(0.0064, device='cuda:0')
# tensor([0.1438], device='cuda:0')
# ---------------------------------------------------
# tensor([0.0096, 0.0078, 0.0167, 0.0134, 0.0119, 0.0064, 0.0077, 0.0339, 0.0096,
#         0.0157], device='cuda:0')
# tensor([0.0222, 0.0470, 0.0239, 0.0177, 0.0475, 0.0194, 0.0454, 0.0548, 0.0447,
#         0.0474], device='cuda:0')
# tensor(0.0064, device='cuda:0')
# tensor([0.1459], device='cuda:0')
# ---------------------------------------------------
# tensor([0.0096, 0.0078, 0.0167, 0.0134, 0.0119, 0.0064, 0.0077, 0.0339, 0.0096,
#         0.0157], device='cuda:0')
# tensor([0.0231, 0.0472, 0.0240, 0.0176, 0.0465, 0.0195, 0.0441, 0.0559, 0.0486,
#         0.0473], device='cuda:0')
# tensor(0.0064, device='cuda:0')
# tensor([0.1406], device='cuda:0')
# ---------------------------------------------------
# tensor([0.0096, 0.0078, 0.0167, 0.0134, 0.0119, 0.0064, 0.0077, 0.0339, 0.0096,
#         0.0157], device='cuda:0')
# tensor([0.0228, 0.0454, 0.0242, 0.0174, 0.0469, 0.0197, 0.0440, 0.0548, 0.0431,
#         0.0481], device='cuda:0')
# tensor(0.0064, device='cuda:0')
# tensor([0.1425], device='cuda:0')
# ---------------------------------------------------
# tensor([0.0096, 0.0078, 0.0167, 0.0134, 0.0119, 0.0064, 0.0077, 0.0339, 0.0096,
#         0.0157], device='cuda:0')
# tensor([0.0233, 0.0439, 0.0260, 0.0180, 0.0479, 0.0184, 0.0437, 0.0533, 0.0416,
#         0.0455], device='cuda:0')
# tensor(0.0064, device='cuda:0')
# tensor([0.1391], device='cuda:0')
# ---------------------------------------------------
# tensor([0.0096, 0.0078, 0.0167, 0.0134, 0.0119, 0.0064, 0.0077, 0.0339, 0.0096,
#         0.0157], device='cuda:0')
# tensor([0.0212, 0.0436, 0.0236, 0.0169, 0.0449, 0.0184, 0.0428, 0.0580, 0.0408,
#         0.0474], device='cuda:0')
# tensor(0.0064, device='cuda:0')
# tensor([0.1534], device='cuda:0')
# ---------------------------------------------------
# tensor([0.0096, 0.0078, 0.0167, 0.0134, 0.0119, 0.0064, 0.0077, 0.0339, 0.0096,
#         0.0157], device='cuda:0')
# tensor([0.0209, 0.0459, 0.0242, 0.0168, 0.0443, 0.0178, 0.0421, 0.0533, 0.0429,
#         0.0456], device='cuda:0')
# tensor(0.0064, device='cuda:0')
# tensor([0.1554], device='cuda:0')
# ---------------------------------------------------
# tensor([0.0096, 0.0078, 0.0167, 0.0134, 0.0119, 0.0064, 0.0077, 0.0339, 0.0096,
#         0.0157], device='cuda:0')
# tensor([0.0216, 0.0421, 0.0241, 0.0165, 0.0435, 0.0189, 0.0432, 0.0538, 0.0406,
#         0.0439], device='cuda:0')
# tensor(0.0064, device='cuda:0')
# tensor([0.1500], device='cuda:0')
# ---------------------------------------------------
# tensor([0.0096, 0.0078, 0.0167, 0.0134, 0.0119, 0.0064, 0.0077, 0.0339, 0.0096,
#         0.0157], device='cuda:0')
# tensor([0.0210, 0.0416, 0.0229, 0.0160, 0.0423, 0.0171, 0.0404, 0.0514, 0.0409,
#         0.0436], device='cuda:0')
# tensor(0.0064, device='cuda:0')
# tensor([0.1546], device='cuda:0')
# ---------------------------------------------------
# tensor([0.0096, 0.0078, 0.0167, 0.0134, 0.0119, 0.0064, 0.0077, 0.0339, 0.0096,
#         0.0157], device='cuda:0')
# tensor([0.0207, 0.0414, 0.0246, 0.0158, 0.0431, 0.0182, 0.0402, 0.0508, 0.0389,
#         0.0423], device='cuda:0')
# tensor(0.0064, device='cuda:0')
# tensor([0.1565], device='cuda:0')
# ---------------------------------------------------
# tensor([0.0096, 0.0078, 0.0167, 0.0134, 0.0119, 0.0064, 0.0077, 0.0339, 0.0096,
#         0.0157], device='cuda:0')
# tensor([0.0200, 0.0396, 0.0234, 0.0158, 0.0434, 0.0167, 0.0392, 0.0509, 0.0409,
#         0.0422], device='cuda:0')
# tensor(0.0064, device='cuda:0')
# tensor([0.1623], device='cuda:0')
# ---------------------------------------------------
# tensor([0.0096, 0.0078, 0.0167, 0.0134, 0.0119, 0.0064, 0.0077, 0.0339, 0.0096,
#         0.0157], device='cuda:0')
# tensor([0.0201, 0.0400, 0.0224, 0.0157, 0.0424, 0.0160, 0.0394, 0.0507, 0.0386,
#         0.0420], device='cuda:0')
# tensor(0.0064, device='cuda:0')
# tensor([0.1614], device='cuda:0')
# ---------------------------------------------------
# tensor([0.0096, 0.0078, 0.0167, 0.0134, 0.0119, 0.0064, 0.0077, 0.0339, 0.0096,
#         0.0157], device='cuda:0')
# tensor([0.0200, 0.0391, 0.0230, 0.0151, 0.0415, 0.0151, 0.0421, 0.0490, 0.0385,
#         0.0412], device='cuda:0')
# tensor(0.0064, device='cuda:0')
# tensor([0.1622], device='cuda:0')
# ---------------------------------------------------
# tensor([0.0096, 0.0078, 0.0167, 0.0134, 0.0119, 0.0064, 0.0077, 0.0339, 0.0096,
#         0.0157], device='cuda:0')
# tensor([0.0188, 0.0395, 0.0211, 0.0147, 0.0408, 0.0141, 0.0381, 0.0491, 0.0378,
#         0.0434], device='cuda:0')
# tensor(0.0064, device='cuda:0')
# tensor([0.1726], device='cuda:0')
# ---------------------------------------------------
# tensor([0.0096, 0.0078, 0.0167, 0.0134, 0.0119, 0.0064, 0.0077, 0.0339, 0.0096,
#         0.0157], device='cuda:0')
# tensor([0.0182, 0.0393, 0.0216, 0.0144, 0.0416, 0.0138, 0.0381, 0.0495, 0.0380,
#         0.0431], device='cuda:0')
# tensor(0.0064, device='cuda:0')
# tensor([0.1783], device='cuda:0')
# ---------------------------------------------------
# tensor([0.0096, 0.0078, 0.0167, 0.0134, 0.0119, 0.0064, 0.0077, 0.0339, 0.0096,
#         0.0157], device='cuda:0')
# tensor([0.0187, 0.0380, 0.0212, 0.0142, 0.0416, 0.0136, 0.0391, 0.0503, 0.0374,
#         0.0427], device='cuda:0')
# tensor(0.0064, device='cuda:0')
# tensor([0.1739], device='cuda:0')
# ---------------------------------------------------
# tensor([0.0096, 0.0078, 0.0167, 0.0134, 0.0119, 0.0064, 0.0077, 0.0339, 0.0096,
#         0.0157], device='cuda:0')
# tensor([0.0177, 0.0382, 0.0212, 0.0141, 0.0404, 0.0135, 0.0369, 0.0508, 0.0392,
#         0.0408], device='cuda:0')
# tensor(0.0064, device='cuda:0')
# tensor([0.1830], device='cuda:0')
# ---------------------------------------------------
# tensor([0.0096, 0.0078, 0.0167, 0.0134, 0.0119, 0.0064, 0.0077, 0.0339, 0.0096,
#         0.0157], device='cuda:0')
# tensor([0.0180, 0.0375, 0.0208, 0.0199, 0.0408, 0.0128, 0.0369, 0.1725, 0.0379,
#         0.0406], device='cuda:0')
# tensor(0.0064, device='cuda:0')
# tensor([0.1800], device='cuda:0')
# ---------------------------------------------------
# tensor([0.0096, 0.0078, 0.0167, 0.0134, 0.0119, 0.0064, 0.0077, 0.0339, 0.0096,
#         0.0157], device='cuda:0')
# tensor([0.0173, 0.0380, 0.0210, 0.0150, 0.0402, 0.0129, 0.0362, 0.0795, 0.0393,
#         0.0404], device='cuda:0')
# tensor(0.0064, device='cuda:0')
# tensor([0.1871], device='cuda:0')
# ---------------------------------------------------
# tensor([0.0096, 0.0078, 0.0167, 0.0134, 0.0119, 0.0064, 0.0077, 0.0339, 0.0096,
#         0.0157], device='cuda:0')
# tensor([0.0168, 0.0371, 0.0218, 0.0161, 0.0402, 0.0125, 0.0359, 0.0510, 0.0378,
#         0.0395], device='cuda:0')
# tensor(0.0064, device='cuda:0')
# tensor([0.1937], device='cuda:0')
# ---------------------------------------------------
# tensor([0.0096, 0.0078, 0.0167, 0.0134, 0.0119, 0.0064, 0.0077, 0.0339, 0.0096,
#         0.0157], device='cuda:0')
# tensor([0.0169, 0.0371, 0.0205, 0.0185, 0.0400, 0.0120, 0.0357, 0.0564, 0.0363,
#         0.0397], device='cuda:0')
# tensor(0.0064, device='cuda:0')
# tensor([0.1916], device='cuda:0')
# ---------------------------------------------------
# tensor([0.0096, 0.0078, 0.0167, 0.0134, 0.0119, 0.0064, 0.0077, 0.0339, 0.0096,
#         0.0157], device='cuda:0')
# tensor([0.0159, 0.0368, 0.0240, 0.0140, 0.0397, 0.0121, 0.0364, 0.0523, 0.0361,
#         0.0401], device='cuda:0')
# tensor(0.0064, device='cuda:0')
# tensor([0.2038], device='cuda:0')
# ---------------------------------------------------
# tensor([0.0096, 0.0078, 0.0167, 0.0134, 0.0119, 0.0064, 0.0077, 0.0339, 0.0096,
#         0.0157], device='cuda:0')
# tensor([0.0170, 0.0372, 0.0223, 0.0272, 0.0397, 0.0115, 0.0353, 0.0564, 0.0362,
#         0.0395], device='cuda:0')
# tensor(0.0064, device='cuda:0')
# tensor([0.1908], device='cuda:0')
# ---------------------------------------------------
# tensor([0.0096, 0.0078, 0.0167, 0.0112, 0.0119, 0.0064, 0.0077, 0.0339, 0.0096,
#         0.0157], device='cuda:0')
# tensor([0.0160, 0.0370, 0.0237, 0.0112, 0.0395, 0.0115, 0.0352, 0.0540, 0.0355,
#         0.0387], device='cuda:0')
# tensor(0.0064, device='cuda:0')
# tensor([0.2033], device='cuda:0')
# ---------------------------------------------------
# tensor([0.0096, 0.0078, 0.0167, 0.0112, 0.0119, 0.0064, 0.0077, 0.0339, 0.0096,
#         0.0157], device='cuda:0')
# tensor([0.0155, 0.0373, 0.0199, 0.0171, 0.0386, 0.0119, 0.0348, 0.0505, 0.0350,
#         0.0384], device='cuda:0')
# tensor(0.0064, device='cuda:0')
# tensor([0.2088], device='cuda:0')
# ---------------------------------------------------
# tensor([0.0096, 0.0078, 0.0167, 0.0112, 0.0119, 0.0064, 0.0077, 0.0339, 0.0096,
#         0.0157], device='cuda:0')
# tensor([0.0150, 0.0371, 0.0227, 0.0183, 0.0382, 0.0117, 0.0348, 0.0522, 0.0354,
#         0.0395], device='cuda:0')
# tensor(0.0064, device='cuda:0')
# tensor([0.2169], device='cuda:0')
# ---------------------------------------------------
# tensor([0.0096, 0.0078, 0.0167, 0.0112, 0.0119, 0.0064, 0.0077, 0.0339, 0.0096,
#         0.0157], device='cuda:0')
# tensor([0.0145, 0.0362, 0.0175, 0.0124, 0.0381, 0.0117, 0.0344, 0.0494, 0.0357,
#         0.0397], device='cuda:0')
# tensor(0.0064, device='cuda:0')
# tensor([0.2238], device='cuda:0')
# ---------------------------------------------------
# tensor([0.0096, 0.0078, 0.0167, 0.0112, 0.0119, 0.0064, 0.0077, 0.0339, 0.0096,
#         0.0157], device='cuda:0')
# tensor([0.0144, 0.0367, 0.0175, 0.0117, 0.0380, 0.0112, 0.0347, 0.0501, 0.0344,
#         0.0393], device='cuda:0')
# tensor(0.0064, device='cuda:0')
# tensor([0.2249], device='cuda:0')
# ---------------------------------------------------
# tensor([0.0096, 0.0078, 0.0167, 0.0095, 0.0119, 0.0064, 0.0077, 0.0339, 0.0096,
#         0.0157], device='cuda:0')
# tensor([0.0140, 0.0351, 0.0197, 0.0095, 0.0376, 0.0105, 0.0346, 0.0508, 0.0338,
#         0.0393], device='cuda:0')
# tensor(0.0064, device='cuda:0')
# tensor([0.2321], device='cuda:0')
# ---------------------------------------------------
# tensor([0.0096, 0.0078, 0.0167, 0.0095, 0.0119, 0.0064, 0.0077, 0.0339, 0.0096,
#         0.0157], device='cuda:0')
# tensor([0.0128, 0.0362, 0.0179, 0.0098, 0.0380, 0.0106, 0.0342, 0.0471, 0.0348,
#         0.0389], device='cuda:0')
# tensor(0.0064, device='cuda:0')
# tensor([0.2541], device='cuda:0')
# ---------------------------------------------------
# tensor([0.0096, 0.0078, 0.0167, 0.0095, 0.0119, 0.0064, 0.0077, 0.0339, 0.0096,
#         0.0157], device='cuda:0')
# tensor([0.0123, 0.0349, 0.0168, 0.0101, 0.0371, 0.0105, 0.0343, 0.0504, 0.0339,
#         0.0378], device='cuda:0')
# tensor(0.0064, device='cuda:0')
# tensor([0.2646], device='cuda:0')
# ---------------------------------------------------
# tensor([0.0096, 0.0078, 0.0156, 0.0095, 0.0119, 0.0064, 0.0077, 0.0339, 0.0096,
#         0.0157], device='cuda:0')
# tensor([0.0115, 0.0351, 0.0156, 0.0098, 0.0371, 0.0104, 0.0338, 0.0520, 0.0360,
#         0.0381], device='cuda:0')
# tensor(0.0064, device='cuda:0')
# tensor([0.2813], device='cuda:0')
# ---------------------------------------------------
# tensor([0.0096, 0.0078, 0.0141, 0.0095, 0.0119, 0.0064, 0.0077, 0.0339, 0.0096,
#         0.0157], device='cuda:0')
# tensor([0.0120, 0.0351, 0.0141, 0.0098, 0.0369, 0.0108, 0.0328, 0.0462, 0.0343,
#         0.0400], device='cuda:0')
# tensor(0.0064, device='cuda:0')
# tensor([0.2715], device='cuda:0')
# ---------------------------------------------------
# tensor([0.0096, 0.0078, 0.0137, 0.0094, 0.0119, 0.0064, 0.0077, 0.0339, 0.0096,
#         0.0157], device='cuda:0')
# tensor([0.0115, 0.0362, 0.0137, 0.0094, 0.0360, 0.0100, 0.0331, 0.0477, 0.0345,
#         0.0378], device='cuda:0')
# tensor(0.0064, device='cuda:0')
# tensor([0.2824], device='cuda:0')
# ---------------------------------------------------
# tensor([0.0096, 0.0078, 0.0136, 0.0094, 0.0119, 0.0064, 0.0077, 0.0339, 0.0096,
#         0.0157], device='cuda:0')
# tensor([0.0118, 0.0350, 0.0136, 0.0099, 0.0356, 0.0102, 0.0325, 0.0459, 0.0339,
#         0.0375], device='cuda:0')
# tensor(0.0064, device='cuda:0')
# tensor([0.2744], device='cuda:0')
# ---------------------------------------------------
# tensor([0.0096, 0.0078, 0.0124, 0.0094, 0.0119, 0.0064, 0.0077, 0.0339, 0.0096,
#         0.0157], device='cuda:0')
# tensor([0.0118, 0.0342, 0.0124, 0.0107, 0.0358, 0.0102, 0.0327, 0.0469, 0.0330,
#         0.0378], device='cuda:0')
# tensor(0.0064, device='cuda:0')
# tensor([0.2761], device='cuda:0')
# ---------------------------------------------------
# tensor([0.0096, 0.0078, 0.0116, 0.0094, 0.0119, 0.0064, 0.0077, 0.0339, 0.0096,
#         0.0157], device='cuda:0')
# tensor([0.0117, 0.0343, 0.0116, 0.0106, 0.0358, 0.0100, 0.0323, 0.0479, 0.0326,
#         0.0369], device='cuda:0')
# tensor(0.0064, device='cuda:0')
# tensor([0.2779], device='cuda:0')
# ---------------------------------------------------
# tensor([0.0096, 0.0078, 0.0116, 0.0094, 0.0119, 0.0064, 0.0077, 0.0339, 0.0096,
#         0.0157], device='cuda:0')
# tensor([0.0111, 0.0342, 0.0151, 0.0103, 0.0360, 0.0095, 0.0326, 0.0466, 0.0330,
#         0.0371], device='cuda:0')
# tensor(0.0064, device='cuda:0')
# tensor([0.2935], device='cuda:0')
# ---------------------------------------------------
# tensor([0.0096, 0.0078, 0.0116, 0.0094, 0.0119, 0.0064, 0.0077, 0.0339, 0.0096,
#         0.0157], device='cuda:0')
# tensor([0.0098, 0.0336, 0.0172, 0.0099, 0.0345, 0.0092, 0.0316, 0.1085, 0.0317,
#         0.0366], device='cuda:0')
# tensor(0.0064, device='cuda:0')
# tensor([0.3325], device='cuda:0')
# ---------------------------------------------------
# tensor([0.0096, 0.0078, 0.0116, 0.0094, 0.0119, 0.0064, 0.0077, 0.0339, 0.0096,
#         0.0157], device='cuda:0')
# tensor([0.0104, 0.0338, 0.0162, 0.0097, 0.0346, 0.0091, 0.0324, 0.1167, 0.0314,
#         0.0362], device='cuda:0')
# tensor(0.0064, device='cuda:0')
# tensor([0.3108], device='cuda:0')
# ---------------------------------------------------
# tensor([0.0096, 0.0078, 0.0116, 0.0094, 0.0119, 0.0064, 0.0077, 0.0339, 0.0096,
#         0.0157], device='cuda:0')
# tensor([0.0100, 0.0331, 0.0134, 0.0095, 0.0346, 0.0086, 0.0314, 0.1031, 0.0319,
#         0.0367], device='cuda:0')
# tensor(0.0064, device='cuda:0')
# tensor([0.3243], device='cuda:0')
# ---------------------------------------------------
# tensor([0.0095, 0.0078, 0.0112, 0.0092, 0.0119, 0.0064, 0.0077, 0.0339, 0.0096,
#         0.0157], device='cuda:0')
# tensor([0.0095, 0.0329, 0.0112, 0.0092, 0.0338, 0.0088, 0.0319, 0.0984, 0.0318,
#         0.0361], device='cuda:0')
# tensor(0.0064, device='cuda:0')
# tensor([0.3331], device='cuda:0')
# ---------------------------------------------------
# tensor([0.0095, 0.0078, 0.0112, 0.0092, 0.0119, 0.0064, 0.0077, 0.0339, 0.0096,
#         0.0157], device='cuda:0')
# tensor([0.0114, 0.0328, 0.0119, 0.0095, 0.0333, 0.0084, 0.0307, 0.0880, 0.0309,
#         0.0354], device='cuda:0')
# tensor(0.0064, device='cuda:0')
# tensor([0.2794], device='cuda:0')
# ---------------------------------------------------
# tensor([0.0095, 0.0078, 0.0112, 0.0092, 0.0119, 0.0064, 0.0077, 0.0339, 0.0096,
#         0.0157], device='cuda:0')
# tensor([0.0121, 0.0326, 0.0129, 0.0097, 0.0325, 0.0090, 0.0305, 0.0777, 0.0323,
#         0.0355], device='cuda:0')
# tensor(0.0064, device='cuda:0')
# tensor([0.2634], device='cuda:0')
# Step = 100 loss = 0.009021.
# ---------------------------------------------------
# tensor([0.0095, 0.0078, 0.0112, 0.0092, 0.0119, 0.0064, 0.0077, 0.0339, 0.0096,
#         0.0157], device='cuda:0')
# tensor([0.0104, 0.0320, 0.0132, 0.0099, 0.0324, 0.0085, 0.0295, 0.0770, 0.0315,
#         0.0350], device='cuda:0')
# tensor(0.0064, device='cuda:0')
# tensor([0.3055], device='cuda:0')
# ---------------------------------------------------
# tensor([0.0095, 0.0078, 0.0112, 0.0092, 0.0119, 0.0064, 0.0077, 0.0339, 0.0096,
#         0.0157], device='cuda:0')
# tensor([0.0099, 0.0308, 0.0127, 0.0096, 0.0325, 0.0088, 0.0303, 0.0680, 0.0309,
#         0.0346], device='cuda:0')
# tensor(0.0064, device='cuda:0')
# tensor([0.3193], device='cuda:0')
# ---------------------------------------------------
# tensor([0.0093, 0.0078, 0.0112, 0.0092, 0.0119, 0.0064, 0.0077, 0.0339, 0.0096,
#         0.0157], device='cuda:0')
# tensor([0.0093, 0.0306, 0.0125, 0.0095, 0.0319, 0.0082, 0.0300, 0.0640, 0.0306,
#         0.0352], device='cuda:0')
# tensor(0.0064, device='cuda:0')
# tensor([0.3182], device='cuda:0')
# ---------------------------------------------------
# tensor([0.0093, 0.0078, 0.0112, 0.0092, 0.0119, 0.0064, 0.0077, 0.0339, 0.0096,
#         0.0157], device='cuda:0')
# tensor([0.0096, 0.0336, 0.0116, 0.0095, 0.0332, 0.0080, 0.0296, 0.0586, 0.0304,
#         0.0350], device='cuda:0')
# tensor(0.0064, device='cuda:0')
# tensor([0.3082], device='cuda:0')
# ---------------------------------------------------
# tensor([0.0093, 0.0078, 0.0111, 0.0092, 0.0119, 0.0064, 0.0077, 0.0339, 0.0096,
#         0.0157], device='cuda:0')
# tensor([0.0103, 0.0314, 0.0111, 0.0095, 0.0322, 0.0084, 0.0290, 0.0548, 0.0297,
#         0.0341], device='cuda:0')
# tensor(0.0064, device='cuda:0')
# tensor([0.2870], device='cuda:0')
# ---------------------------------------------------
# tensor([0.0093, 0.0078, 0.0111, 0.0092, 0.0119, 0.0064, 0.0077, 0.0339, 0.0096,
#         0.0157], device='cuda:0')
# tensor([0.0107, 0.0312, 0.0116, 0.0094, 0.0315, 0.0083, 0.0288, 0.0523, 0.0294,
#         0.0332], device='cuda:0')
# tensor(0.0064, device='cuda:0')
# tensor([0.2781], device='cuda:0')
# ---------------------------------------------------
# tensor([0.0093, 0.0078, 0.0111, 0.0092, 0.0119, 0.0064, 0.0077, 0.0339, 0.0096,
#         0.0157], device='cuda:0')
# tensor([0.0105, 0.0309, 0.0116, 0.0095, 0.0317, 0.0081, 0.0285, 0.0523, 0.0324,
#         0.0327], device='cuda:0')
# tensor(0.0064, device='cuda:0')
# tensor([0.2819], device='cuda:0')
# ---------------------------------------------------
# tensor([0.0093, 0.0078, 0.0111, 0.0092, 0.0119, 0.0064, 0.0077, 0.0339, 0.0096,
#         0.0157], device='cuda:0')
# tensor([0.0105, 0.0311, 0.0111, 0.0095, 0.0313, 0.0077, 0.0280, 0.0489, 0.0301,
#         0.0330], device='cuda:0')
# tensor(0.0064, device='cuda:0')
# tensor([0.2820], device='cuda:0')
# ---------------------------------------------------
# tensor([0.0093, 0.0078, 0.0111, 0.0092, 0.0119, 0.0064, 0.0077, 0.0339, 0.0096,
#         0.0157], device='cuda:0')
# tensor([0.0105, 0.0309, 0.0114, 0.0094, 0.0310, 0.0077, 0.0276, 0.0462, 0.0306,
#         0.0320], device='cuda:0')
# tensor(0.0064, device='cuda:0')
# tensor([0.2814], device='cuda:0')
# ---------------------------------------------------
# tensor([0.0093, 0.0078, 0.0111, 0.0092, 0.0119, 0.0064, 0.0077, 0.0339, 0.0096,
#         0.0157], device='cuda:0')
# tensor([0.0101, 0.0302, 0.0115, 0.0092, 0.0304, 0.0077, 0.0275, 0.0447, 0.0299,
#         0.0330], device='cuda:0')
# tensor(0.0064, device='cuda:0')
# tensor([0.2933], device='cuda:0')
# ---------------------------------------------------
# tensor([0.0093, 0.0078, 0.0111, 0.0090, 0.0119, 0.0064, 0.0077, 0.0339, 0.0096,
#         0.0157], device='cuda:0')
# tensor([0.0097, 0.0303, 0.0116, 0.0090, 0.0299, 0.0073, 0.0281, 0.0461, 0.0289,
#         0.0326], device='cuda:0')
# tensor(0.0064, device='cuda:0')
# tensor([0.3050], device='cuda:0')
# ---------------------------------------------------
# tensor([0.0093, 0.0078, 0.0111, 0.0088, 0.0119, 0.0064, 0.0077, 0.0339, 0.0096,
#         0.0157], device='cuda:0')
# tensor([0.0094, 0.0301, 0.0116, 0.0088, 0.0299, 0.0069, 0.0284, 0.0480, 0.0280,
#         0.0329], device='cuda:0')
# tensor(0.0064, device='cuda:0')
# tensor([0.3170], device='cuda:0')
# ---------------------------------------------------
# tensor([0.0092, 0.0078, 0.0111, 0.0088, 0.0119, 0.0064, 0.0077, 0.0339, 0.0096,
#         0.0157], device='cuda:0')
# tensor([0.0092, 0.0294, 0.0114, 0.0088, 0.0291, 0.0068, 0.0272, 0.0500, 0.0333,
#         0.0340], device='cuda:0')
# tensor(0.0064, device='cuda:0')
# tensor([0.3075], device='cuda:0')
# ---------------------------------------------------
# tensor([0.0092, 0.0078, 0.0111, 0.0088, 0.0119, 0.0064, 0.0077, 0.0339, 0.0096,
#         0.0157], device='cuda:0')
# tensor([0.0093, 0.0295, 0.0113, 0.0088, 0.0298, 0.0073, 0.0270, 0.0526, 0.0290,
#         0.0324], device='cuda:0')
# tensor(0.0064, device='cuda:0')
# tensor([0.3031], device='cuda:0')
# ---------------------------------------------------
# tensor([0.0092, 0.0078, 0.0111, 0.0088, 0.0119, 0.0064, 0.0077, 0.0339, 0.0096,
#         0.0157], device='cuda:0')
# tensor([0.0098, 0.0298, 0.0111, 0.0088, 0.0302, 0.0070, 0.0270, 0.0534, 0.0325,
#         0.0322], device='cuda:0')
# tensor(0.0064, device='cuda:0')
# tensor([0.2887], device='cuda:0')
# ---------------------------------------------------
# tensor([0.0092, 0.0078, 0.0111, 0.0087, 0.0119, 0.0064, 0.0077, 0.0339, 0.0096,
#         0.0157], device='cuda:0')
# tensor([0.0098, 0.0302, 0.0112, 0.0087, 0.0295, 0.0077, 0.0271, 0.0546, 0.0294,
#         0.0324], device='cuda:0')
# tensor(0.0064, device='cuda:0')
# tensor([0.2871], device='cuda:0')
# ---------------------------------------------------
# tensor([0.0092, 0.0078, 0.0111, 0.0086, 0.0119, 0.0064, 0.0077, 0.0339, 0.0096,
#         0.0157], device='cuda:0')
# tensor([0.0100, 0.0290, 0.0111, 0.0086, 0.0288, 0.0071, 0.0263, 0.0555, 0.0286,
#         0.0317], device='cuda:0')
# tensor(0.0064, device='cuda:0')
# tensor([0.2830], device='cuda:0')
# ---------------------------------------------------
# tensor([0.0092, 0.0078, 0.0111, 0.0085, 0.0119, 0.0064, 0.0077, 0.0339, 0.0096,
#         0.0157], device='cuda:0')
# tensor([0.0101, 0.0291, 0.0113, 0.0085, 0.0288, 0.0074, 0.0261, 0.0587, 0.0285,
#         0.0315], device='cuda:0')
# tensor(0.0064, device='cuda:0')
# tensor([0.2808], device='cuda:0')
# ---------------------------------------------------
# tensor([0.0092, 0.0078, 0.0111, 0.0085, 0.0119, 0.0064, 0.0077, 0.0339, 0.0096,
#         0.0157], device='cuda:0')
# tensor([0.0097, 0.0283, 0.0113, 0.0085, 0.0286, 0.0066, 0.0265, 0.0583, 0.0280,
#         0.0315], device='cuda:0')
# tensor(0.0064, device='cuda:0')
# tensor([0.2913], device='cuda:0')
# ---------------------------------------------------
# tensor([0.0092, 0.0078, 0.0111, 0.0085, 0.0119, 0.0062, 0.0077, 0.0339, 0.0096,
#         0.0157], device='cuda:0')
# tensor([0.0095, 0.0275, 0.0114, 0.0085, 0.0285, 0.0062, 0.0259, 0.0535, 0.0272,
#         0.0313], device='cuda:0')
# tensor(0.0062, device='cuda:0')
# tensor([0.3158], device='cuda:0')
# ---------------------------------------------------
# tensor([0.0092, 0.0078, 0.0111, 0.0085, 0.0119, 0.0062, 0.0077, 0.0339, 0.0096,
#         0.0157], device='cuda:0')
# tensor([0.0096, 0.0297, 0.0113, 0.0085, 0.0285, 0.0111, 0.0254, 0.0583, 0.0275,
#         0.0317], device='cuda:0')
# tensor(0.0062, device='cuda:0')
# tensor([0.3105], device='cuda:0')
# ---------------------------------------------------
# tensor([0.0092, 0.0078, 0.0111, 0.0084, 0.0119, 0.0062, 0.0077, 0.0339, 0.0096,
#         0.0157], device='cuda:0')
# tensor([0.0098, 0.0286, 0.0114, 0.0084, 0.0286, 0.0099, 0.0251, 0.0530, 0.0273,
#         0.0301], device='cuda:0')
# tensor(0.0062, device='cuda:0')
# tensor([0.3056], device='cuda:0')
# ---------------------------------------------------
# tensor([0.0092, 0.0078, 0.0111, 0.0084, 0.0119, 0.0062, 0.0077, 0.0339, 0.0096,
#         0.0157], device='cuda:0')
# tensor([0.0098, 0.0284, 0.0113, 0.0084, 0.0285, 0.0077, 0.0258, 0.0527, 0.0288,
#         0.0321], device='cuda:0')
# tensor(0.0062, device='cuda:0')
# tensor([0.3048], device='cuda:0')
# ---------------------------------------------------
# tensor([0.0092, 0.0078, 0.0111, 0.0083, 0.0119, 0.0062, 0.0077, 0.0339, 0.0096,
#         0.0157], device='cuda:0')
# tensor([0.0098, 0.0279, 0.0114, 0.0083, 0.0279, 0.0082, 0.0259, 0.0508, 0.0280,
#         0.0314], device='cuda:0')
# tensor(0.0062, device='cuda:0')
# tensor([0.3056], device='cuda:0')
# ---------------------------------------------------
# tensor([0.0092, 0.0078, 0.0111, 0.0083, 0.0119, 0.0062, 0.0077, 0.0339, 0.0096,
#         0.0157], device='cuda:0')
# tensor([0.0097, 0.0273, 0.0114, 0.0083, 0.0272, 0.0073, 0.0247, 0.0485, 0.0274,
#         0.0305], device='cuda:0')
# tensor(0.0062, device='cuda:0')
# tensor([0.3076], device='cuda:0')
# ---------------------------------------------------
# tensor([0.0092, 0.0078, 0.0111, 0.0083, 0.0119, 0.0062, 0.0077, 0.0339, 0.0096,
#         0.0157], device='cuda:0')
# tensor([0.0098, 0.0281, 0.0113, 0.0083, 0.0262, 0.0071, 0.0252, 0.0498, 0.0262,
#         0.0315], device='cuda:0')
# tensor(0.0062, device='cuda:0')
# tensor([0.3066], device='cuda:0')
# ---------------------------------------------------
# tensor([0.0092, 0.0078, 0.0111, 0.0082, 0.0119, 0.0062, 0.0077, 0.0339, 0.0096,
#         0.0157], device='cuda:0')
# tensor([0.0100, 0.0268, 0.0114, 0.0082, 0.0269, 0.0073, 0.0254, 0.0546, 0.0260,
#         0.0292], device='cuda:0')
# tensor(0.0062, device='cuda:0')
# tensor([0.2996], device='cuda:0')
# ---------------------------------------------------
# tensor([0.0092, 0.0078, 0.0111, 0.0082, 0.0119, 0.0062, 0.0077, 0.0339, 0.0096,
#         0.0157], device='cuda:0')
# tensor([0.0097, 0.0265, 0.0113, 0.0082, 0.0256, 0.0071, 0.0249, 0.0517, 0.0258,
#         0.0298], device='cuda:0')
# tensor(0.0062, device='cuda:0')
# tensor([0.3096], device='cuda:0')
# ---------------------------------------------------
# tensor([0.0092, 0.0078, 0.0111, 0.0082, 0.0119, 0.0062, 0.0077, 0.0339, 0.0096,
#         0.0157], device='cuda:0')
# tensor([0.0098, 0.0278, 0.0114, 0.0082, 0.0253, 0.0072, 0.0242, 0.0462, 0.0255,
#         0.0307], device='cuda:0')
# tensor(0.0062, device='cuda:0')
# tensor([0.3042], device='cuda:0')
# ---------------------------------------------------
# tensor([0.0092, 0.0078, 0.0111, 0.0082, 0.0119, 0.0062, 0.0077, 0.0339, 0.0096,
#         0.0157], device='cuda:0')
# tensor([0.0096, 0.0269, 0.0115, 0.0082, 0.0262, 0.0072, 0.0246, 0.0389, 0.0249,
#         0.0284], device='cuda:0')
# tensor(0.0062, device='cuda:0')
# tensor([0.3104], device='cuda:0')
# ---------------------------------------------------
# tensor([0.0092, 0.0078, 0.0111, 0.0081, 0.0119, 0.0062, 0.0077, 0.0339, 0.0096,
#         0.0157], device='cuda:0')
# tensor([0.0097, 0.0259, 0.0115, 0.0081, 0.0260, 0.0069, 0.0234, 0.4914, 0.0255,
#         0.0282], device='cuda:0')
# tensor(0.0062, device='cuda:0')
# tensor([0.3086], device='cuda:0')
# ---------------------------------------------------
# tensor([0.0092, 0.0078, 0.0111, 0.0081, 0.0119, 0.0062, 0.0077, 0.0339, 0.0096,
#         0.0157], device='cuda:0')
# tensor([0.0100, 0.0260, 0.0114, 0.0081, 0.0266, 0.0068, 0.0235, 0.3433, 0.0251,
#         0.0283], device='cuda:0')
# tensor(0.0062, device='cuda:0')
# tensor([0.2986], device='cuda:0')
# ---------------------------------------------------
# tensor([0.0092, 0.0078, 0.0111, 0.0080, 0.0119, 0.0062, 0.0077, 0.0339, 0.0096,
#         0.0157], device='cuda:0')
# tensor([0.0097, 0.0261, 0.0112, 0.0080, 0.0257, 0.0068, 0.0235, 0.2180, 0.0246,
#         0.0275], device='cuda:0')
# tensor(0.0062, device='cuda:0')
# tensor([0.3073], device='cuda:0')
# ---------------------------------------------------
# tensor([0.0092, 0.0078, 0.0111, 0.0079, 0.0119, 0.0062, 0.0077, 0.0339, 0.0096,
#         0.0157], device='cuda:0')
# tensor([0.0098, 0.0268, 0.0111, 0.0079, 0.0250, 0.0066, 0.0234, 0.1564, 0.0241,
#         0.0283], device='cuda:0')
# tensor(0.0062, device='cuda:0')
# tensor([0.3064], device='cuda:0')
# ---------------------------------------------------
# tensor([0.0092, 0.0078, 0.0111, 0.0079, 0.0119, 0.0062, 0.0077, 0.0339, 0.0096,
#         0.0157], device='cuda:0')
# tensor([0.0094, 0.0254, 0.0111, 0.0079, 0.0251, 0.0066, 0.0232, 0.1294, 0.0247,
#         0.0284], device='cuda:0')
# tensor(0.0062, device='cuda:0')
# tensor([0.3186], device='cuda:0')
# ---------------------------------------------------
# tensor([0.0092, 0.0078, 0.0111, 0.0077, 0.0119, 0.0062, 0.0077, 0.0339, 0.0096,
#         0.0157], device='cuda:0')
# tensor([0.0093, 0.0261, 0.0112, 0.0077, 0.0249, 0.0066, 0.0227, 0.0958, 0.0235,
#         0.0285], device='cuda:0')
# tensor(0.0062, device='cuda:0')
# tensor([0.3204], device='cuda:0')
# ---------------------------------------------------
# tensor([0.0092, 0.0078, 0.0107, 0.0076, 0.0119, 0.0062, 0.0077, 0.0339, 0.0096,
#         0.0157], device='cuda:0')
# tensor([0.0095, 0.0258, 0.0107, 0.0076, 0.0248, 0.0064, 0.0224, 0.0953, 0.0241,
#         0.0278], device='cuda:0')
# tensor(0.0062, device='cuda:0')
# tensor([0.3155], device='cuda:0')
# ---------------------------------------------------
# tensor([0.0092, 0.0078, 0.0104, 0.0075, 0.0119, 0.0062, 0.0077, 0.0339, 0.0096,
#         0.0157], device='cuda:0')
# tensor([0.0093, 0.0250, 0.0104, 0.0075, 0.0239, 0.0064, 0.0224, 0.0939, 0.0240,
#         0.0277], device='cuda:0')
# tensor(0.0062, device='cuda:0')
# tensor([0.3216], device='cuda:0')
# ---------------------------------------------------
# tensor([0.0092, 0.0078, 0.0104, 0.0074, 0.0119, 0.0062, 0.0077, 0.0339, 0.0096,
#         0.0157], device='cuda:0')
# tensor([0.0095, 0.0240, 0.0106, 0.0074, 0.0317, 0.0063, 0.0237, 0.0881, 0.0232,
#         0.0280], device='cuda:0')
# tensor(0.0062, device='cuda:0')
# tensor([0.3162], device='cuda:0')
# ---------------------------------------------------
# tensor([0.0092, 0.0078, 0.0104, 0.0073, 0.0119, 0.0062, 0.0077, 0.0339, 0.0096,
# ...
# ---------------------------------------------------
# tensor([0.0010, 0.0078, 0.0010, 0.0010, 0.0032, 0.0011, 0.0077, 0.0137, 0.0096,
#         0.0036], device='cuda:0')
# tensor([0.0012, 0.0555, 0.0010, 0.0013, 0.0503, 0.0017, 0.2797, 0.0479, 0.0924,
#         0.1009], device='cuda:0')
# tensor(0.0010, device='cuda:0')
# tensor([0.0086], device='cuda:0')
# ---------------------------------------------------
# tensor([0.0010, 0.0078, 0.0010, 0.0010, 0.0032, 0.0011, 0.0077, 0.0137, 0.0096,
#         0.0036], device='cuda:0')
# tensor([0.0013, 0.0467, 0.0010, 0.0013, 0.0806, 0.0019, 0.1874, 0.0741, 0.2046,
#         0.0878], device='cuda:0')
# tensor(0.0010, device='cuda:0')
# tensor([0.0079], device='cuda:0')
# ---------------------------------------------------
# tensor([0.0010, 0.0078, 0.0010, 0.0010, 0.0032, 0.0011, 0.0077, 0.0137, 0.0096,
#         0.0036], device='cuda:0')
# tensor([0.0014, 0.2586, 0.0011, 0.0014, 0.0442, 0.0016, 0.2306, 0.0497, 0.2209,
#         0.1374], device='cuda:0')
# tensor(0.0010, device='cuda:0')
# tensor([0.0071], device='cuda:0')
# ---------------------------------------------------
# tensor([0.0010, 0.0078, 0.0010, 0.0010, 0.0032, 0.0011, 0.0077, 0.0137, 0.0096,
#         0.0036], device='cuda:0')
# tensor([0.0014, 0.1198, 0.0011, 0.0015, 0.0412, 0.0026, 0.0650, 0.0542, 0.2979,
#         0.0602], device='cuda:0')
# tensor(0.0010, device='cuda:0')
# tensor([0.0072], device='cuda:0')
# ---------------------------------------------------
# tensor([0.0010, 0.0078, 0.0010, 0.0010, 0.0032, 0.0011, 0.0077, 0.0137, 0.0096,
#         0.0036], device='cuda:0')
# tensor([0.0013, 0.0516, 0.0011, 0.0016, 0.0374, 0.0039, 0.0882, 0.1130, 0.1134,
#         0.1279], device='cuda:0')
# tensor(0.0010, device='cuda:0')
# tensor([0.0079], device='cuda:0')
# ---------------------------------------------------
# tensor([0.0010, 0.0078, 0.0010, 0.0010, 0.0032, 0.0011, 0.0077, 0.0137, 0.0096,
#         0.0036], device='cuda:0')
# tensor([0.0013, 0.0895, 0.0011, 0.0015, 0.0438, 0.0040, 0.1424, 0.0791, 0.1235,
#         0.0585], device='cuda:0')
# tensor(0.0010, device='cuda:0')
# tensor([0.0076], device='cuda:0')
# ---------------------------------------------------
# tensor([0.0010, 0.0078, 0.0010, 0.0010, 0.0032, 0.0011, 0.0077, 0.0137, 0.0096,
#         0.0036], device='cuda:0')
# tensor([0.0013, 0.1472, 0.0012, 0.0014, 0.0253, 0.0024, 0.1598, 0.0640, 0.0426,
#         0.0672], device='cuda:0')
# tensor(0.0010, device='cuda:0')
# tensor([0.0074], device='cuda:0')
# ---------------------------------------------------
# tensor([0.0010, 0.0078, 0.0010, 0.0010, 0.0032, 0.0011, 0.0077, 0.0137, 0.0096,
#         0.0036], device='cuda:0')
# tensor([0.0015, 0.0841, 0.0012, 0.0013, 0.0669, 0.0028, 0.0823, 0.0829, 0.1601,
#         0.0670], device='cuda:0')
# tensor(0.0010, device='cuda:0')
# tensor([0.0069], device='cuda:0')
# ---------------------------------------------------
# tensor([0.0010, 0.0078, 0.0010, 0.0010, 0.0032, 0.0011, 0.0077, 0.0137, 0.0096,
#         0.0036], device='cuda:0')
# tensor([0.0016, 0.1256, 0.0011, 0.0012, 0.0432, 0.0014, 0.0856, 0.0530, 0.0739,
#         0.0651], device='cuda:0')
# tensor(0.0010, device='cuda:0')
# tensor([0.0062], device='cuda:0')
# ---------------------------------------------------
# tensor([0.0010, 0.0078, 0.0010, 0.0010, 0.0032, 0.0011, 0.0077, 0.0137, 0.0096,
#         0.0036], device='cuda:0')
# tensor([0.0017, 0.2748, 0.0011, 0.0012, 0.0768, 0.0015, 0.1629, 0.0702, 0.1707,
#         0.0795], device='cuda:0')
# tensor(0.0010, device='cuda:0')
# tensor([0.0060], device='cuda:0')
# ---------------------------------------------------
# tensor([0.0010, 0.0078, 0.0010, 0.0010, 0.0032, 0.0011, 0.0077, 0.0137, 0.0096,
#         0.0036], device='cuda:0')
# tensor([0.0018, 0.7428, 0.0010, 0.0011, 0.0629, 0.0046, 0.3880, 0.0581, 0.1408,
#         0.0972], device='cuda:0')
# tensor(0.0010, device='cuda:0')
# tensor([0.0055], device='cuda:0')
# ---------------------------------------------------
# tensor([0.0010, 0.0078, 0.0010, 0.0010, 0.0032, 0.0011, 0.0077, 0.0137, 0.0096,
#         0.0036], device='cuda:0')
# tensor([0.0019, 0.1471, 0.0010, 0.0011, 0.0872, 0.0029, 0.2403, 0.0748, 0.1309,
#         0.0889], device='cuda:0')
# tensor(0.0010, device='cuda:0')
# tensor([0.0051], device='cuda:0')
# ---------------------------------------------------
# tensor([0.0010, 0.0078, 0.0010, 0.0010, 0.0032, 0.0011, 0.0077, 0.0137, 0.0096,
#         0.0036], device='cuda:0')
# tensor([0.0020, 0.1460, 0.0010, 0.0012, 0.0458, 0.0013, 0.1453, 0.2237, 0.0835,
#         0.0836], device='cuda:0')
# tensor(0.0010, device='cuda:0')
# tensor([0.0049], device='cuda:0')
# ---------------------------------------------------
# tensor([0.0010, 0.0078, 0.0010, 0.0010, 0.0032, 0.0011, 0.0077, 0.0137, 0.0096,
#         0.0036], device='cuda:0')
# tensor([0.0019, 0.1371, 0.0010, 0.0012, 0.0477, 0.0025, 0.1248, 0.1503, 0.1323,
#         0.0605], device='cuda:0')
# tensor(0.0010, device='cuda:0')
# tensor([0.0053], device='cuda:0')
# ---------------------------------------------------
# tensor([0.0010, 0.0078, 0.0010, 0.0010, 0.0032, 0.0011, 0.0077, 0.0137, 0.0096,
#         0.0036], device='cuda:0')
# tensor([0.0017, 0.1886, 0.0011, 0.0012, 0.0188, 0.0025, 0.1608, 0.0901, 0.1225,
#         0.0564], device='cuda:0')
# tensor(0.0010, device='cuda:0')
# tensor([0.0059], device='cuda:0')
# ---------------------------------------------------
# tensor([0.0010, 0.0078, 0.0010, 0.0010, 0.0032, 0.0011, 0.0077, 0.0137, 0.0096,
#         0.0036], device='cuda:0')
# tensor([0.0019, 0.0445, 0.0011, 0.0012, 0.0198, 0.0014, 0.1168, 0.0774, 0.0991,
#         0.0897], device='cuda:0')
# tensor(0.0010, device='cuda:0')
# tensor([0.0053], device='cuda:0')
# ---------------------------------------------------
# tensor([0.0010, 0.0078, 0.0010, 0.0010, 0.0032, 0.0011, 0.0077, 0.0137, 0.0096,
#         0.0036], device='cuda:0')
# tensor([0.0024, 0.1637, 0.0012, 0.0012, 0.0159, 0.0015, 0.1840, 0.0466, 0.6465,
#         0.0829], device='cuda:0')
# tensor(0.0010, device='cuda:0')
# tensor([0.0041], device='cuda:0')
# ---------------------------------------------------
# tensor([0.0010, 0.0078, 0.0010, 0.0010, 0.0032, 0.0011, 0.0077, 0.0137, 0.0096,
#         0.0036], device='cuda:0')
# tensor([0.0028, 0.2109, 0.0012, 0.0012, 0.0731, 0.0011, 0.3146, 0.0775, 0.0629,
#         0.1908], device='cuda:0')
# tensor(0.0010, device='cuda:0')
# tensor([0.0035], device='cuda:0')
# ---------------------------------------------------
# tensor([0.0010, 0.0078, 0.0010, 0.0010, 0.0032, 0.0011, 0.0077, 0.0137, 0.0096,
#         0.0036], device='cuda:0')
# tensor([0.0031, 0.0773, 0.0012, 0.0013, 0.0248, 0.0011, 0.1281, 0.0405, 0.0581,
#         0.1276], device='cuda:0')
# tensor(0.0010, device='cuda:0')
# tensor([0.0032], device='cuda:0')
# ---------------------------------------------------
# tensor([0.0010, 0.0078, 0.0010, 0.0010, 0.0032, 0.0011, 0.0077, 0.0137, 0.0096,
#         0.0036], device='cuda:0')
# tensor([0.0038, 0.0890, 0.0013, 0.0013, 0.0571, 0.0019, 0.3649, 0.0361, 0.0721,
#         0.0713], device='cuda:0')
# tensor(0.0010, device='cuda:0')
# tensor([0.0026], device='cuda:0')
# ---------------------------------------------------
# tensor([0.0010, 0.0078, 0.0010, 0.0010, 0.0032, 0.0011, 0.0077, 0.0137, 0.0096,
#         0.0036], device='cuda:0')
# tensor([0.0042, 0.3027, 0.0013, 0.0014, 0.1009, 0.0014, 0.3161, 0.0647, 0.2418,
#         0.0925], device='cuda:0')
# tensor(0.0010, device='cuda:0')
# tensor([0.0024], device='cuda:0')
# ---------------------------------------------------
# tensor([0.0010, 0.0078, 0.0010, 0.0010, 0.0032, 0.0011, 0.0077, 0.0137, 0.0096,
#         0.0036], device='cuda:0')
# tensor([0.0041, 0.1193, 0.0014, 0.0014, 0.0720, 0.0030, 0.0975, 0.0454, 0.1656,
#         0.2659], device='cuda:0')
# tensor(0.0010, device='cuda:0')
# tensor([0.0024], device='cuda:0')
# ---------------------------------------------------
# tensor([0.0010, 0.0078, 0.0010, 0.0010, 0.0032, 0.0011, 0.0077, 0.0137, 0.0096,
#         0.0036], device='cuda:0')
# tensor([0.0038, 0.1255, 0.0015, 0.0013, 0.0568, 0.0021, 0.2160, 0.0587, 0.0297,
#         0.1208], device='cuda:0')
# tensor(0.0010, device='cuda:0')
# tensor([0.0026], device='cuda:0')
# ---------------------------------------------------
# tensor([0.0010, 0.0078, 0.0010, 0.0010, 0.0032, 0.0011, 0.0077, 0.0137, 0.0096,
#         0.0036], device='cuda:0')
# tensor([0.0036, 0.0574, 0.0016, 0.0012, 0.0483, 0.0031, 0.1694, 0.0455, 0.0683,
#         0.1498], device='cuda:0')
# tensor(0.0010, device='cuda:0')
# tensor([0.0027], device='cuda:0')
# ---------------------------------------------------
# tensor([0.0010, 0.0078, 0.0010, 0.0010, 0.0032, 0.0011, 0.0077, 0.0137, 0.0096,
#         0.0036], device='cuda:0')
# tensor([0.0038, 0.0655, 0.0018, 0.0012, 0.0523, 0.0018, 0.1071, 0.1045, 0.0958,
#         0.4273], device='cuda:0')
# tensor(0.0010, device='cuda:0')
# tensor([0.0026], device='cuda:0')
# ---------------------------------------------------
# tensor([0.0010, 0.0078, 0.0010, 0.0010, 0.0032, 0.0011, 0.0077, 0.0137, 0.0096,
#         0.0036], device='cuda:0')
# tensor([0.0047, 0.0762, 0.0019, 0.0011, 0.0652, 0.0017, 0.2443, 0.0495, 0.1594,
#         0.1376], device='cuda:0')
# tensor(0.0010, device='cuda:0')
# tensor([0.0021], device='cuda:0')
# ---------------------------------------------------
# tensor([0.0010, 0.0078, 0.0010, 0.0010, 0.0032, 0.0011, 0.0077, 0.0137, 0.0096,
#         0.0036], device='cuda:0')
# tensor([0.0052, 0.1387, 0.0019, 0.0011, 0.0556, 0.0026, 0.0568, 0.0603, 0.2873,
#         0.0813], device='cuda:0')
# tensor(0.0010, device='cuda:0')
# tensor([0.0019], device='cuda:0')
# ---------------------------------------------------
# tensor([0.0010, 0.0078, 0.0010, 0.0010, 0.0032, 0.0011, 0.0077, 0.0137, 0.0096,
#         0.0036], device='cuda:0')
# tensor([0.0058, 0.3449, 0.0018, 0.0011, 0.0621, 0.0015, 0.0896, 0.0742, 0.1209,
#         0.0918], device='cuda:0')
# tensor(0.0010, device='cuda:0')
# tensor([0.0017], device='cuda:0')
# ---------------------------------------------------
# tensor([0.0010, 0.0078, 0.0010, 0.0010, 0.0032, 0.0011, 0.0077, 0.0137, 0.0096,
#         0.0036], device='cuda:0')
# tensor([0.0067, 0.0881, 0.0016, 0.0011, 0.0321, 0.0023, 0.1522, 0.0645, 0.0502,
#         0.0641], device='cuda:0')
# tensor(0.0010, device='cuda:0')
# tensor([0.0015], device='cuda:0')
# ---------------------------------------------------
# tensor([0.0010, 0.0078, 0.0010, 0.0010, 0.0032, 0.0011, 0.0077, 0.0137, 0.0096,
#         0.0036], device='cuda:0')
# tensor([0.0072, 0.1093, 0.0014, 0.0012, 0.1501, 0.0017, 0.3312, 0.0582, 0.1394,
#         0.0581], device='cuda:0')
# tensor(0.0010, device='cuda:0')
# tensor([0.0014], device='cuda:0')
# ---------------------------------------------------
# tensor([0.0010, 0.0078, 0.0010, 0.0010, 0.0032, 0.0011, 0.0077, 0.0137, 0.0096,
#         0.0036], device='cuda:0')
# tensor([0.0060, 0.0515, 0.0012, 0.0012, 0.0365, 0.0017, 0.4707, 0.0599, 0.0822,
#         0.0575], device='cuda:0')
# tensor(0.0010, device='cuda:0')
# tensor([0.0017], device='cuda:0')
# ---------------------------------------------------
# tensor([0.0010, 0.0078, 0.0010, 0.0010, 0.0032, 0.0011, 0.0077, 0.0137, 0.0096,
#         0.0036], device='cuda:0')
# tensor([0.0049, 0.1555, 0.0011, 0.0011, 0.1207, 0.0014, 0.0914, 0.0717, 0.1193,
#         0.0712], device='cuda:0')
# tensor(0.0010, device='cuda:0')
# tensor([0.0020], device='cuda:0')
# ---------------------------------------------------
# tensor([0.0010, 0.0078, 0.0010, 0.0010, 0.0032, 0.0011, 0.0077, 0.0137, 0.0096,
#         0.0036], device='cuda:0')
# tensor([0.0033, 0.1900, 0.0011, 0.0011, 0.1823, 0.0015, 0.1218, 0.0721, 0.1876,
#         0.1155], device='cuda:0')
# tensor(0.0010, device='cuda:0')
# tensor([0.0030], device='cuda:0')
# ---------------------------------------------------
# tensor([0.0010, 0.0078, 0.0010, 0.0010, 0.0032, 0.0011, 0.0077, 0.0137, 0.0096,
#         0.0036], device='cuda:0')
# tensor([0.0016, 0.2108, 0.0010, 0.0011, 0.0909, 0.0014, 0.1066, 0.1020, 0.1518,
#         0.1089], device='cuda:0')
# tensor(0.0010, device='cuda:0')
# tensor([0.0062], device='cuda:0')
# ---------------------------------------------------
# tensor([0.0010, 0.0078, 0.0010, 0.0010, 0.0032, 0.0011, 0.0077, 0.0137, 0.0096,
#         0.0036], device='cuda:0')
# tensor([0.0011, 0.0596, 0.0011, 0.0011, 0.0711, 0.0033, 0.3053, 0.3197, 0.0723,
#         0.0709], device='cuda:0')
# tensor(0.0010, device='cuda:0')
# tensor([0.0094], device='cuda:0')
# ---------------------------------------------------
# tensor([0.0010, 0.0078, 0.0010, 0.0010, 0.0032, 0.0011, 0.0077, 0.0137, 0.0096,
#         0.0036], device='cuda:0')
# tensor([0.0011, 0.0510, 0.0011, 0.0010, 0.0576, 0.0016, 0.1945, 0.2491, 0.0284,
#         0.0730], device='cuda:0')
# tensor(0.0010, device='cuda:0')
# tensor([0.0094], device='cuda:0')
# ---------------------------------------------------
# tensor([0.0010, 0.0078, 0.0010, 0.0010, 0.0032, 0.0011, 0.0077, 0.0137, 0.0096,
#         0.0036], device='cuda:0')
# tensor([0.0011, 0.0748, 0.0011, 0.0010, 0.0335, 0.0023, 0.4534, 0.2217, 0.1188,
#         0.0667], device='cuda:0')
# tensor(0.0010, device='cuda:0')
# tensor([0.0093], device='cuda:0')
# ---------------------------------------------------
# tensor([0.0010, 0.0078, 0.0010, 0.0010, 0.0032, 0.0011, 0.0077, 0.0137, 0.0096,
#         0.0036], device='cuda:0')
# tensor([0.0010, 0.2870, 0.0010, 0.0010, 0.0502, 0.0041, 0.0986, 0.1699, 0.1260,
#         0.0717], device='cuda:0')
# tensor(0.0010, device='cuda:0')
# tensor([0.0095], device='cuda:0')
# ---------------------------------------------------
# tensor([0.0010, 0.0078, 0.0010, 0.0010, 0.0032, 0.0011, 0.0077, 0.0137, 0.0096,
#         0.0036], device='cuda:0')
# tensor([0.0011, 0.3266, 0.0010, 0.0010, 0.0745, 0.0060, 0.1703, 0.0945, 0.1505,
#         0.0918], device='cuda:0')
# tensor(0.0010, device='cuda:0')
# tensor([0.0114], device='cuda:0')
# ---------------------------------------------------
# tensor([0.0010, 0.0078, 0.0010, 0.0010, 0.0032, 0.0011, 0.0077, 0.0137, 0.0096,
#         0.0036], device='cuda:0')
# tensor([0.0012, 0.0958, 0.0011, 0.0010, 0.0643, 0.0045, 0.2601, 0.2627, 0.2765,
#         0.0978], device='cuda:0')
# tensor(0.0010, device='cuda:0')
# tensor([0.0108], device='cuda:0')
# ---------------------------------------------------
# tensor([0.0010, 0.0078, 0.0010, 0.0010, 0.0032, 0.0011, 0.0077, 0.0137, 0.0096,
#         0.0036], device='cuda:0')
# tensor([0.0011, 0.3659, 0.0010, 0.0010, 0.0242, 0.0023, 0.0699, 0.2764, 0.1104,
#         0.1949], device='cuda:0')
# tensor(0.0010, device='cuda:0')
# tensor([0.0116], device='cuda:0')
# ---------------------------------------------------
# tensor([0.0010, 0.0078, 0.0010, 0.0010, 0.0032, 0.0011, 0.0077, 0.0137, 0.0096,
#         0.0036], device='cuda:0')
# tensor([0.0012, 0.1331, 0.0010, 0.0010, 0.1350, 0.0018, 0.0742, 0.0724, 0.0919,
#         0.1856], device='cuda:0')
# tensor(0.0010, device='cuda:0')
# tensor([0.0110], device='cuda:0')
# ---------------------------------------------------
# tensor([0.0010, 0.0078, 0.0010, 0.0010, 0.0032, 0.0011, 0.0077, 0.0137, 0.0096,
#         0.0036], device='cuda:0')
# tensor([0.0012, 0.0440, 0.0010, 0.0010, 0.0439, 0.0014, 0.1834, 0.1077, 0.1312,
#         0.0830], device='cuda:0')
# tensor(0.0010, device='cuda:0')
# tensor([0.0113], device='cuda:0')
# ---------------------------------------------------
# tensor([0.0010, 0.0078, 0.0010, 0.0010, 0.0032, 0.0011, 0.0077, 0.0137, 0.0096,
#         0.0036], device='cuda:0')
# tensor([0.0011, 0.0488, 0.0010, 0.0010, 0.1105, 0.0014, 0.2928, 0.1176, 0.0922,
#         0.0743], device='cuda:0')
# tensor(0.0010, device='cuda:0')
# tensor([0.0123], device='cuda:0')
# ---------------------------------------------------
# tensor([0.0010, 0.0078, 0.0010, 0.0010, 0.0032, 0.0011, 0.0077, 0.0137, 0.0096,
#         0.0036], device='cuda:0')
# tensor([0.0011, 0.2945, 0.0010, 0.0010, 0.0526, 0.0011, 0.1003, 0.0469, 0.1844,
#         0.3435], device='cuda:0')
# tensor(0.0010, device='cuda:0')
# tensor([0.0126], device='cuda:0')
# ---------------------------------------------------
# tensor([0.0010, 0.0078, 0.0010, 0.0010, 0.0032, 0.0011, 0.0077, 0.0137, 0.0096,
#         0.0036], device='cuda:0')
# tensor([0.0011, 0.1378, 0.0010, 0.0010, 0.0383, 0.0016, 0.1926, 0.0447, 0.2152,
#         0.2488], device='cuda:0')
# tensor(0.0010, device='cuda:0')
# tensor([0.0128], device='cuda:0')
# Step = 3000 loss = 0.001027.
# RMSE_pso=  0.03212951237654007
